# %% [markdown]
# # Run the cell below to open the interactive pipeline launcher

# %%
import sys, os

if "google.colab" in sys.modules:
    # 1. Clone if we are not in the repo and the repo dir doesn't exist
    if not os.path.exists("src") and not os.path.exists("colab-phage-assembly"):
        # !git clone https://github.com/leightonpayne/colab-phage-assembly.git
    
    # 2. Enter the repository directory if it exists
    if os.path.exists("colab-phage-assembly"):
        os.chdir("colab-phage-assembly")

# Add source directory to path
sys.path.append(os.path.abspath("src"))

import pipeline
from boilerplate.utils import setup_colab

setup_colab()
pipeline.launch()
