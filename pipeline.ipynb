# %% [markdown]
# # Run the cell below to open the interactive pipeline launcher

# %%
import sys, os, shutil

if "google.colab" in sys.modules and not os.path.exists("src"):
    repo_name = "colab-phage-assembly"
    
    if os.path.exists(repo_name) and not os.path.exists(os.path.join(repo_name, "src")):
        shutil.rmtree(repo_name)
    
    if not os.path.exists(repo_name):
        # !git clone -q https://github.com/leightonpayne/colab-phage-assembly.git

    if os.path.exists(repo_name):
        os.chdir(repo_name)

sys.path.append("src")
import pipeline
from boilerplate.utils import setup_colab

setup_colab()
pipeline.launch()
